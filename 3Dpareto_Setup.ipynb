# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
pareto_Data = pd.ExcelFile('3DParetoData_Setup.xlsx')

# %%
df_P1S2 = pd.read_excel(pareto_Data, 'P1S2')
df_P2S2 = pd.read_excel(pareto_Data, 'P2S2')
df_P3S2 = pd.read_excel(pareto_Data, 'P3S2')
df_P4S2 = pd.read_excel(pareto_Data, 'P4S2')
df_P5S2 = pd.read_excel(pareto_Data, 'P5S2')

# %%
x_P1S2 = (df_P1S2['p_cost']).to_numpy().T
y_P1S2 = (df_P1S2['p_time']).to_numpy().T
z_P1S2 = (df_P1S2['makespan']).to_numpy().T

# %%
# Creating figure
fig = plt.figure(figsize = (10, 10))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x_P1S2, y_P1S2, z_P1S2, color = "green")
plt.title("P1S2")
ax.set_xlabel('p_cost', fontweight ='bold')
ax.set_ylabel('p_time', fontweight ='bold')
ax.set_zlabel('makespan', fontweight ='bold')
plt.savefig("P1S2_Setup.jpg")

# %%
x_P2S2 = (df_P2S2['p_cost']).to_numpy().T
y_P2S2 = (df_P2S2['p_time']).to_numpy().T
z_P2S2 = (df_P2S2['makespan']).to_numpy().T

# %%
# Creating figure
fig = plt.figure(figsize = (10, 10))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x_P2S2, y_P2S2, z_P2S2, color = "green")
plt.title("P2S2")
ax.set_xlabel('p_cost', fontweight ='bold')
ax.set_ylabel('p_time', fontweight ='bold')
ax.set_zlabel('makespan', fontweight ='bold')
plt.savefig("P2S2_Setup.jpg")

# %%
x_P3S2 = (df_P3S2['p_cost']).to_numpy().T
y_P3S2 = (df_P3S2['p_time']).to_numpy().T
z_P3S2 = (df_P3S2['makespan']).to_numpy().T

# %%
# Creating figure
fig = plt.figure(figsize = (10, 10))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x_P3S2, y_P3S2, z_P3S2, color = "green")
plt.title("P3S2")
ax.set_xlabel('p_cost', fontweight ='bold')
ax.set_ylabel('p_time', fontweight ='bold')
ax.set_zlabel('makespan', fontweight ='bold')
plt.savefig("P3S2_Setup.jpg")

# %%
x_P4S2 = (df_P4S2['p_cost']).to_numpy().T
y_P4S2 = (df_P4S2['p_time']).to_numpy().T
z_P4S2 = (df_P4S2['makespan']).to_numpy().T

# %%
# Creating figure
fig = plt.figure(figsize = (10, 10))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x_P4S2, y_P4S2, z_P4S2, color = "green")
plt.title("P4S2")
ax.set_xlabel('p_cost', fontweight ='bold')
ax.set_ylabel('p_time', fontweight ='bold')
ax.set_zlabel('makespan', fontweight ='bold')
plt.savefig("P4S2_Setup.jpg")

# %%
x_P5S2 = (df_P5S2['p_cost']).to_numpy().T
y_P5S2 = (df_P5S2['p_time']).to_numpy().T
z_P5S2 = (df_P5S2['makespan']).to_numpy().T

# %%
# Creating figure
fig = plt.figure(figsize = (10, 10))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x_P5S2, y_P5S2, z_P5S2, color = "green")
plt.title("P5S2")
ax.set_xlabel('p_cost', fontweight ='bold')
ax.set_ylabel('p_time', fontweight ='bold')
ax.set_zlabel('makespan', fontweight ='bold')
plt.savefig("P5S2_Setup.jpg")
